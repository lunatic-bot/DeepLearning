# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = r"C:\Users\atalb\Documents\Coding\DeepLearning\Datasets\Churn_Modelling.csv"
dataset = pd.read_csv(data_path)

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
## Create dummy variables
geography = pd.get_dummies(X['Geography'], drop_first=True)
gender = pd.get_dummies(X['Gender'], drop_first=True)


## Concatenate the Dataframes
X = pd.concat([X, geography, gender], axis=1)
## drop unnecessary columns
X = X.drop(['Gender', 'Geography'], axis=1)

# %%
## split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
## Creating the ANN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU, ELU, Dropout

# %%
## initialize the ANN
classifier = Sequential()

# %%
## Adding the input layer and first hidden layer
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', input_dim=11))
classifier.add(Dropout(0.3))
# Out:
# c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
## Adding the second hidden layer
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
classifier.add(Dropout(0.4))

## Adding the third hidden layer
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
classifier.add(Dropout(0.2))

## Adding the output layer
classifier.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

# %%
## Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 6)              │            42 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 6)              │            42 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 163 (652.00 B)
#  Trainable params: 163 (652.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
## Fitting the ANN to the Training set
model_history = classifier.fit(X_train, y_train, validation_split=0.33, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6544 - loss: 0.6997 - val_accuracy: 0.7974 - val_loss: 0.5195
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7880 - loss: 0.5269 - val_accuracy: 0.7955 - val_loss: 0.4908
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7979 - loss: 0.5063 - val_accuracy: 0.7955 - val_loss: 0.4807
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7968 - loss: 0.4997 - val_accuracy: 0.7955 - val_loss: 0.4817
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7974 - loss: 0.4907 - val_accuracy: 0.7959 - val_loss: 0.4735
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7983 - loss: 0.4788 - val_accuracy: 0.7959 - val_loss: 0.4593
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7990 - loss: 0.4702 - val_accuracy: 0.7967 - val_loss: 0.4528
# Epoch 8/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8011 - loss: 0.4711 - val_accuracy: 0.7959 - val_loss: 0.4490
# Epoch 9/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7994 - loss: 0.4695 - val_accuracy: 0.7959 - val_loss: 0.4486
# Epoch 10/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7968 - loss: 0.4668 - val_accuracy: 0.7955 - val_loss: 0.4475
# Epoch 11/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7994 - loss: 0.4561 - val_accuracy: 0.7986 - val_loss: 0.4385
# Epoch 12/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8039 - loss: 0.4562 - val_accuracy: 0.7963 - val_loss: 0.4342
# Epoch 13/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.
100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8291 - loss: 0.4082 - val_accuracy: 0.8285 - val_loss: 0.3841
# Epoch 75/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8354 - loss: 0.4058 - val_accuracy: 0.8391 - val_loss: 0.3796
# Epoch 76/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8352 - loss: 0.4027 - val_accuracy: 0.8360 - val_loss: 0.3803
# Epoch 77/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8283 - loss: 0.4064 - val_accuracy: 0.8410 - val_loss: 0.3798
# Epoch 78/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8304 - loss: 0.4055 - val_accuracy: 0.8342 - val_loss: 0.3834
# Epoch 79/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8358 - loss: 0.3996 - val_accuracy: 0.8357 - val_loss: 0.3795
# Epoch 80/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8322 - loss: 0.4057 - val_accuracy: 0.8360 - val_loss: 0.3800
# Epoch 81/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8287 - loss: 0.4051 - val_accuracy: 0.8353 - val_loss: 0.3798
# Epoch 82/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8276 - loss: 0.4123 - val_accuracy: 0.8330 - val_loss: 0.3820
# Epoch 83/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8356 - loss: 0.3988 - val_accuracy: 0.8402 - val_loss: 0.3769
# Epoch 84/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8358 - loss: 0.3976 - val_accuracy: 0.8372 - val_loss: 0.3788
# Epoch 85/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8386 - loss: 0.3967 - val_accuracy: 0.8432 - val_loss: 0.3756
# Epoch 86/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8328 - loss: 0.4062 - val_accuracy: 0.8357 - val_loss: 0.3799
# Epoch 87/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8367 - loss: 0.3951 - val_accuracy: 0.8383 - val_loss: 0.3753
# Epoch 88/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8358 - loss: 0.3980 - val_accuracy: 0.8395 - val_loss: 0.3757
# Epoch 89/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8373 - loss: 0.4021 - val_accuracy: 0.8413 - val_loss: 0.3741
# Epoch 90/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8302 - loss: 0.4049 - val_accuracy: 0.8376 - val_loss: 0.3756
# Epoch 91/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8296 - loss: 0.4084 - val_accuracy: 0.8402 - val_loss: 0.3771
# Epoch 92/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8330 - loss: 0.3995 - val_accuracy: 0.8338 - val_loss: 0.3786
# Epoch 93/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8334 - loss: 0.4019 - val_accuracy: 0.8417 - val_loss: 0.3768
# Epoch 94/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8324 - loss: 0.4066 - val_accuracy: 0.8425 - val_loss: 0.3760
# Epoch 95/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8319 - loss: 0.3990 - val_accuracy: 0.8391 - val_loss: 0.3743
# Epoch 96/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8375 - loss: 0.3964 - val_accuracy: 0.8391 - val_loss: 0.3749
# Epoch 97/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8358 - loss: 0.4021 - val_accuracy: 0.8402 - val_loss: 0.3753
# Epoch 98/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8328 - loss: 0.4028 - val_accuracy: 0.8395 - val_loss: 0.3799
# Epoch 99/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8377 - loss: 0.4012 - val_accuracy: 0.8410 - val_loss: 0.3765
# Epoch 100/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8393 - loss: 0.3978 - val_accuracy: 0.8395 - val_loss: 0.3749

# %%
## list all data in history
print(model_history.history.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## list all data in history
# ----> 2 print(model_history.history.keys())
#
# NameError: name 'model_history' is not defined

# %%
## summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
## Making the predictions and evaluating the model
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
## confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1523,   72],
#        [ 206,  199]])

# %%
## calculate the accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.861
