# %% [markdown]
# ### from ccolab -  convert ML models to deep learning models
#
# ## ML model can use GPu and run in pytorch

# %%
# !pip install hummingbird-ml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.5/166.5 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 102.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from hummingbird.ml import convert

## create some random data for binary classification
num_classes = 2
X = np.random.rand(100000, 28)
y = np.random.randint(num_classes, size=100000)

## create random forest classifier (rf) and fit the model

# %%
## create and train model
skl_model = RandomForestClassifier(n_estimators=10, max_depth=10)
skl_model.fit(X, y)

## convert skl model to hummingbird model
model = convert(skl_model, 'pytorch')

# %%
# %%timeit -r 3
model.predict(X)
# Out:
# 117 ms ± 4.47 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
## run prediction on GPU
# %%timeit -r 3
model.to('cuda')
model.predict(X)
# Out:
# 11.6 ms ± 77.7 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
