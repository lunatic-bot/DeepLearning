# %% [markdown]
# **Image Segmentation**
#
# > PixelLib is a library for performing segmentation of objects in images and videos. It supports the two major types of image segmentation.

# %%
# !pip install pixellib
# Out:
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pixellib) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from pixellib) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from pixellib) (4.13.0.92)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.10.0)
# Collecting imgaug (from pixellib)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting labelme2coco (from pixellib)
#   Downloading labelme2coco-0.2.6-py3-none-any.whl.metadata (3.5 kB)
# Collecting imantics (from pixellib)
#   Downloading imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.0.12)
# Collecting pyQt5 (from pixellib)
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting fvcore (from pixellib)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath (from pixellib)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from pixellib) (2.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.1.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.3.0)
# Collecting yacs (from pixellib)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from pixellib) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pixellib) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pixellib) (1.0.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from pixellib) (4.0.1)
# Collecting dataclasses (from pixellib)
#   Downloading dataclasses-0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting hydra-core (from pixellib)
#   Downloading hydra_core-1.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting black (from pixellib)
#   Downloading black-26.5.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black->pixellib) (8.4.1)
# Collecting mypy-extensions>=0.4.3 (from black->pixellib)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from black->pixellib) (26.2)
# Collecting pathspec>=1.0.0 (from black->pixellib)
#   Downloading pathspec-1.1.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black->pixellib) (4.10.0)
# Collecting pytokens~=0.4.0 (from black->pixellib)
#   Downloading pytokens-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from fvcore->pixellib) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->pixellib) (6.0.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from iopath->pixellib) (4.15.0)
# Collecting portalocker (from iopath->pixellib)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->pixellib) (4.9.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from imantics->pixellib) (6.1.1)
# Collecting xmljson (from imantics->pixellib)
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (1.16.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (2.37.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pixellib) (3.6.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pixellib) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pixellib) (0.5)
# Collecting sahi>=0.8.19 (from labelme2coco->pixellib)
#   Downloading sahi-0.12.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from labelme2coco->pixellib) (4.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (2.9.0.post0)
# Collecting PyQt5-sip<13,>=12.15 (from pyQt5->pixellib)
#   Downloading pyqt5_sip-12.18.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (495 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyQt5->pixellib)
#   Downloading pyqt5_qt5-5.15.19-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (2026.5.1)
# Collecting fire (from sahi>=0.8.19->labelme2coco->pixellib)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2026.5.20)
# Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.3/430.3 kB 15.7 MB/s eta 0:00:00
# Downloading black-26.5.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 47.2 MB/s eta 0:00:00
# Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading hydra_core-1.3.3-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 13.2 MB/s eta 0:00:00
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 48.6 MB/s eta 0:00:00
# Downloading labelme2coco-0.2.6-py3-none-any.whl (19 kB)
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 74.6 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.1.1-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 5.3 MB/s eta 0:00:00
# Downloading pyqt5_qt5-5.15.19-py3-none-manylinux2014_x86_64.whl (60.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 10.2 MB/s eta 0:00:00
# Downloading pyqt5_sip-12.18.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.whl (282 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 12.9 MB/s eta 0:00:00
# Downloading pytokens-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 12.1 MB/s eta 0:00:00
# Downloading sahi-0.12.1-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 8.2 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.2 MB/s eta 0:00:00
# Building wheels for collected packages: fvcore, iopath, imantics
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=690fce25630b896311a43737e11ac1c0ec5f7728c97227430a5b59dbc4b92c39
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=904831829cf24a886bdeee7f6f45b5e6af6666f07fa1fb1e212c519cf181bd31
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
#   Building wheel for imantics (setup.py) ... done
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16009 sha256=7aa1b3c4595ba7680b0f8b0928e7f75f2f6f17b539fdf0a0583a5389d16c5255
#   Stored in directory: /root/.cache/pip/wheels/40/e1/8d/fd1fa8f30722831661afc8e6efcda609c72d1b73e11f4d49b7
# Successfully built fvcore iopath imantics
# Installing collected packages: xmljson, PyQt5-Qt5, dataclasses, yacs, pytokens, PyQt5-sip, portalocker, pathspec, mypy-extensions, fire, sahi, pyQt5, iopath, imantics, hydra-core, black, imgaug, fvcore, labelme2coco, pixellib
# Successfully installed PyQt5-Qt5-5.15.19 PyQt5-sip-12.18.0 black-26.5.1 dataclasses-0.6 fire-0.7.1 fvcore-0.1.5.post20221221 hydra-core-1.3.3 imantics-0.1.12 imgaug-0.4.0 iopath-0.1.10 labelme2coco-0.2.6 mypy-extensions-1.1.0 pathspec-1.1.1 pixellib-0.7.1 portalocker-3.2.0 pyQt5-5.15.11 pytokens-0.4.1 sahi-0.12.1 xmljson-0.2.1 yacs-0.1.8

# %%
import pixellib
from pixellib.instance import instance_segmentation

# %%
segment_image = instance_segmentation()
segment_image.load_model("mask_rcnn_coco.h5")
segment_image.segmentImage("image.jpg", output_image_name = "output.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_17322/1053075453.py in <cell line: 0>()
#       1 segment_image = instance_segmentation()
# ----> 2 segment_image.load_model("mask_rcnn_coco.h5")
#       3 segment_image.segmentImage("image.jpg", output_image_name = "output.jpg")
#
# /usr/local/lib/python3.12/dist-packages/pixellib/instance/__init__.py in load_model(self, model_path, confidence)
#      63         self.model = MaskRCNN(mode = "inference", model_dir = self.model_dir, config = coco_config)
#      64
# ---> 65         self.model.load_weights(model_path, by_name= True)
#      66
#      67
#
# /usr/local/lib/python3.12/dist-packages/pixellib/instance/mask_rcnn.py in load_weights(self, filepath, by_name, exclude)
#    2093         if h5py is None:
#    2094             raise ImportError('`load_weights` requires h5py.')
# -> 2095         with h5py.File(filepath, mode='r') as f:
#    2096             if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2097                 f = f['model_weights']
#
# /usr/local/lib/python3.12/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     553                                  fs_strategy=fs_strategy, fs_persist=fs_persist,
#     554                                  fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 555                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     556
#     557             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.12/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     230         if swmr:
#     231             flags |= h5f.ACC_SWMR_READ
# --> 232         fid = h5f.open(name, flags, fapl=fapl)
#     233     elif mode == 'r+':
#     234         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'mask_rcnn_coco.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
