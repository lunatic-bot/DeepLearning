# %% [markdown]
# ##### Keras Tuner - Decide the number of hidden layers and the number of hidden neurons

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

from kerastuner import HyperModel, RandomSearch
# Out:
# C:\Users\atalb\AppData\Local\Temp\ipykernel_18760\2771968064.py:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import HyperModel, RandomSearch

# %%
## Air quality dataset
dataset_path = r"C:\Users\atalb\Documents\Coding\DeepLearning\Datasets\Real_Combine.csv"
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i), min_value=32, max_value=512, step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                    loss='mean_absolute_error',
                    metrics=['mean_absolute_error'])
    return model

# %% [markdown]
# ## hyperparameters
# 1. How many number of hidden layers
# 2. How many number of hidden neurons we should have in hidden layers
# 3. Learning rate

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='project_1',
    project_name='air_quality_index'
)
# Out:
# Reloading Tuner from project_1\air_quality_index\tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
tuner.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |6                 |num_layers
# 480               |192               |units_0
# 160               |96                |units_1
# 0.001             |0.001             |learning_rate
#
# WARNING:tensorflow:From c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/5
# WARNING:tensorflow:From c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 24/24 [==============================] - 2s 22ms/step - loss: 79.5866 - mean_absolute_error: 79.5866 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 7ms/step - loss: 66.6590 - mean_absolute_error: 66.6590 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 7ms/step - loss: 64.1960 - mean_absolute_error: 64.1960 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 7ms/step - loss: 62.5492 - mean_absolute_error: 62.5492 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 9ms/step - loss: 61.7898 - mean_absolute_error: 61.7898 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# 24/24 [==============================] - 2s 17ms/step - loss: 69.5805 - mean_absolute_error: 69.5805 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 7ms/step - loss: 65.6069 - mean_absolute_error: 65.6069 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 7ms/step - loss: 62.0126 - mean_absolute_error: 62.0126 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 7ms/step - loss: 60.2230 - mean_absolute_error: 60.2230 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 10ms/step - loss: 56.3221 - mean_absolute_error: 56.3221 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# 24/24 [==============================] - 2s 18ms/step - loss: 77.8208 - mean_absolute_error: 77.8208 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 7ms/step - loss: 65.7718 - mean_absolute_error: 65.7718 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 7ms/step - loss: 63.3974 - mean_absolute_error: 63.3974 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 7ms/step - loss: 63.1931 - mean_absolute_error: 63.1931 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 7ms/step - loss: 60.0510 - mean_absolute_error: 60.0510 - val_loss: nan - val_mean_absolute_error: nan
# c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\metrics_tracking.py:111: RuntimeWarning: All-NaN axis encountered
#   np.nanmin(values) if self.direction == "min" else np.nanmax(values)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tuner.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
#
# File c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     232     self.on_trial_begin(trial)
#     233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:338, in BaseTuner.on_trial_end(self, trial)
#     332 def on_trial_end(self, trial):
#     333     """Called at the end of a trial.
#     334
#     335     Args:
#     336         trial: A `Trial` instance.
#     337     """
# --> 338     self.oracle.end_trial(trial)
#     339     self.save()
#
# File c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\oracle.py:586, in Oracle.end_trial(self, trial)
#     584 if not self._retry(trial):
#     585     self.end_order.append(trial.trial_id)
# --> 586     self._check_consecutive_failures()
#     588 self._save_trial(trial)
#     589 self.save()
#
# File c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\oracle.py:543, in Oracle._check_consecutive_failures(self)
#     541     consecutive_failures = 0
#     542 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 543     raise RuntimeError(
#     544         "Number of consecutive failures exceeded the limit "
#     545         f"of {self.max_consecutive_failed_trials}.\n"
#     546         + (trial.message or "")
#     547     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.
# Traceback (most recent call last):
#   File "c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 239, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 309, in run_trial
#     self._configure_tensorboard_dir(callbacks, trial, execution)
#   File "c:\Users\atalb\Documents\Coding\DeepLearning\.venv\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 421, in _configure_tensorboard_dir
#     from tensorboard.plugins.hparams import api as hparams_api
# ModuleNotFoundError: No module named 'tensorboard'

# %%
tuner.results_summary()

# %%
from tensorboard.plugins.hparams import api as hparams_api
